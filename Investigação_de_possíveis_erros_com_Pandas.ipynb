# %% [markdown]
# <a href="https://colab.research.google.com/github/Juan-Matheus/JuanMatheus/blob/main/Investiga%C3%A7%C3%A3o_de_poss%C3%ADveis_erros_com_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Nesse Projeto Vamos realizar uma investigação da base de dados utilizando o Panda para a descoberta de possíveis erros!!

# %%
df=pd.read_csv(r'agricultural_raw_material.csv')

# %%
df
# Out:
#       Month Coarse wool Price Coarse wool price % Change Copra Price  \
# 0    Apr-90            482.34                          -         236
# 1    May-90            447.26                     -7.27%         234
# 2    Jun-90            440.99                     -1.40%         216
# 3    Jul-90            418.44                     -5.11%         205
# 4    Aug-90            418.44                      0.00%         198
# ..      ...               ...                        ...         ...
# 356  Dec-19               NaN                        NaN         NaN
# 357  Jan-20               NaN                        NaN         NaN
# 358  Feb-20               NaN                        NaN         NaN
# 359  Mar-20               NaN                        NaN         NaN
# 360  Apr-20               NaN                        NaN         NaN
#
#     Copra price % Change  Cotton Price Cotton price % Change Fine wool Price  \
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
# 5 primeiras linhas
df.head()
# Out:
#     Month Coarse wool Price Coarse wool price % Change Copra Price  \
# 0  Apr-90            482.34                          -         236
# 1  May-90            447.26                     -7.27%         234
# 2  Jun-90            440.99                     -1.40%         216
# 3  Jul-90            418.44                     -5.11%         205
# 4  Aug-90            418.44                      0.00%         198
#
#   Copra price % Change  Cotton Price Cotton price % Change Fine wool Price  \
# 0                    -          1.83                     -        1,071.63
# 1               -0.85%          1.89                 3.28%        1,057.18
# 2               -7.69%          1.99                 5.29%          898.24
# 3               -5.09%          2.01                 1.01%          895.83
# 4               -3.41%          1.79               -10.95%          951.22
#
#   Fine wool price % Change  Hard log Price  ... Plywood Price  \
# ...

# %%
# 5 Últimas linas
df.tail()
# Out:
#       Month Coarse wool Price Coarse wool price % Change Copra Price  \
# 356  Dec-19               NaN                        NaN         NaN
# 357  Jan-20               NaN                        NaN         NaN
# 358  Feb-20               NaN                        NaN         NaN
# 359  Mar-20               NaN                        NaN         NaN
# 360  Apr-20               NaN                        NaN         NaN
#
#     Copra price % Change  Cotton Price Cotton price % Change Fine wool Price  \
# 356                  NaN          1.67                 1.21%             NaN
# 357                  NaN          1.74                 4.19%             NaN
# 358                  NaN          1.69                -2.87%             NaN
# 359                  NaN          1.49               -11.83%             NaN
# 360                  NaN          1.40                -6.04%             NaN
#
#     Fine wool price % Change  Hard log Price  ... Plywood Price  \
# ...

# %%
#quantidade de linhas e colunas
df.shape
# Out:
# (361, 25)

# %%
#Verificando as colunas
df.columns
# Out:
# Index(['Month', 'Coarse wool Price', 'Coarse wool price % Change',
#        'Copra Price', 'Copra price % Change', 'Cotton Price',
#        'Cotton price % Change', 'Fine wool Price', 'Fine wool price % Change',
#        'Hard log Price', 'Hard log price % Change', 'Hard sawnwood Price',
#        'Hard sawnwood price % Change', 'Hide Price', 'Hide price % change',
#        'Plywood Price', 'Plywood price % Change', 'Rubber Price',
#        'Rubber price % Change', 'Softlog Price', 'Softlog price % Change',
#        'Soft sawnwood Price', 'Soft sawnwood price % Change',
#        'Wood pulp Price', 'Wood pulp price % Change'],
#       dtype='object')

# %%
#verificando linhas duplicadas
df.duplicated().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 361 entries, 0 to 360
# Data columns (total 25 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Month                         361 non-null    object
#  1   Coarse wool Price             327 non-null    object
#  2   Coarse wool price % Change    327 non-null    object
#  3   Copra Price                   339 non-null    object
#  4   Copra price % Change          339 non-null    object
#  5   Cotton Price                  361 non-null    float64
#  6   Cotton price % Change         361 non-null    object
#  7   Fine wool Price               327 non-null    object
#  8   Fine wool price % Change      327 non-null    object
#  9   Hard log Price                361 non-null    float64
#  10  Hard log price % Change       361 non-null    object
#  11  Hard sawnwood Price           327 non-null    float64
# ...

# %%
#verifica a existÊncia de NaN
df.isna().sum()
# Out:
# Month                            0
# Coarse wool Price               34
# Coarse wool price % Change      34
# Copra Price                     22
# Copra price % Change            22
# Cotton Price                     0
# Cotton price % Change            0
# Fine wool Price                 34
# Fine wool price % Change        34
# Hard log Price                   0
# Hard log price % Change          0
# Hard sawnwood Price             34
# Hard sawnwood price % Change    34
# Hide Price                      34
# Hide price % change             34
# Plywood Price                    0
# Plywood price % Change           0
# Rubber Price                     0
# Rubber price % Change            0
# Softlog Price                   34
# Softlog price % Change          34
# Soft sawnwood Price             34
# Soft sawnwood price % Change    34
# Wood pulp Price                  1
# Wood pulp price % Change         1
# dtype: int64

# %%
# Sumário Estatistico
df.describe()
# Out:
#        Cotton Price  Hard log Price  Hard sawnwood Price  Hide Price  \
# count    361.000000      361.000000           327.000000  327.000000
# mean       1.640000      251.034072           707.950367   78.566667
# std        0.513319       65.628406           144.563241   13.690623
# min        0.820000      133.280000           413.370000   28.590000
# 25%        1.290000      197.960000           573.470000   69.495000
# 50%        1.600000      253.010000           728.710000   77.250000
# 75%        1.850000      282.970000           831.635000   86.000000
# max        5.060000      520.810000           973.600000  114.630000
#
#        Plywood Price  Rubber Price  Softlog Price  Soft sawnwood Price  \
# count     361.000000    361.000000     327.000000           327.000000
# mean      508.216122      1.656427     164.527462           291.061713
# std        89.274718      1.017086      25.596308            34.113959
# ...

# %%
# sumário estatistico - inclusive para as variáveis categóricas
df.describe(include = "all")
# Out:
#          Month Coarse wool Price Coarse wool price % Change Copra Price  \
# count      361               327                        327         339
# unique     361               324                        293         263
# top     Apr-90            418.44                      0.69%         412
# freq         1                 2                          3           4
# mean       NaN               NaN                        NaN         NaN
# std        NaN               NaN                        NaN         NaN
# min        NaN               NaN                        NaN         NaN
# 25%        NaN               NaN                        NaN         NaN
# 50%        NaN               NaN                        NaN         NaN
# 75%        NaN               NaN                        NaN         NaN
# max        NaN               NaN                        NaN         NaN
#
#        Copra price % Change  Cotton Price Cotton price % Change  \
# ...

# %%
# quantidade de valores únicos em cada coluna
df.nunique()
# Out:
# Month                           361
# Coarse wool Price               324
# Coarse wool price % Change      293
# Copra Price                     263
# Copra price % Change            307
# Cotton Price                    134
# Cotton price % Change           296
# Fine wool Price                 325
# Fine wool price % Change        300
# Hard log Price                  350
# Hard log price % Change         325
# Hard sawnwood Price             291
# Hard sawnwood price % Change    257
# Hide Price                      298
# Hide price % change             277
# Plywood Price                   349
# Plywood price % Change          286
# Rubber Price                    185
# Rubber price % Change           302
# Softlog Price                   316
# Softlog price % Change          300
# Soft sawnwood Price             316
# Soft sawnwood price % Change    297
# Wood pulp Price                 287
# Wood pulp price % Change        259
# dtype: int64

# %%
#valores únicos
df['Cotton Price'].unique()
# Out:
# array([1.83, 1.89, 1.99, 2.01, 1.79, 1.82, 1.85, 1.87, 1.86, 1.78, 1.7 ,
#        1.62, 1.55, 1.5 , 1.4 , 1.36, 1.31, 1.24, 1.22, 1.28, 1.34, 1.41,
#        1.44, 1.32, 1.25, 1.17, 1.16, 1.2 , 1.26, 1.33, 1.35, 1.3 , 1.27,
#        1.21, 1.53, 1.8 , 1.9 , 1.69, 1.66, 1.63, 1.71, 1.92, 2.11, 2.23,
#        2.44, 2.51, 2.53, 2.  , 1.93, 1.88, 1.97, 1.94, 1.76, 1.68, 1.75,
#        1.77, 1.74, 1.64, 1.59, 1.52, 1.51, 1.45, 1.42, 1.54, 1.46, 1.23,
#        1.29, 1.12, 1.09, 1.05, 1.02, 0.97, 1.18, 1.13, 1.1 , 1.  , 0.96,
#        0.91, 0.82, 0.84, 0.95, 0.94, 0.93, 0.88, 1.03, 1.08, 1.15, 1.6 ,
#        1.67, 1.19, 1.07, 1.47, 1.61, 1.65, 1.72, 1.37, 1.14, 1.43, 1.58,
#        2.05, 2.31, 2.79, 3.41, 3.7 , 3.94, 4.7 , 5.06, 4.78, 3.65, 3.18,
#        2.69, 2.52, 2.58, 2.1 , 2.22, 2.19, 2.2 , 1.95, 1.81, 1.84, 1.98,
#        2.08, 2.03, 2.04, 2.07, 2.14, 1.49, 1.48, 1.73, 1.91, 2.15, 2.12,
#        1.56, 1.57])

# %%
#ordenando as colunas
df.sort_values(["Cotton Price"])
# Out:
#       Month Coarse wool Price Coarse wool price % Change Copra Price  \
# 138  Oct-01            330.29                     -3.01%         195
# 139  Nov-01            335.91                      1.70%         202
# 145  May-02            519.78                     -1.01%         263
# 137  Sep-01            340.53                     -2.41%         210
# 144  Apr-02            525.07                     -0.77%         244
# ..      ...               ...                        ...         ...
# 248  Dec-10            883.84                     -0.64%    1,154.00
# 249  Jan-11          1,011.45                     14.44%    1,354.00
# 250  Feb-11          1,060.91                      4.89%    1,503.00
# 252  Apr-11          1,309.26                      8.25%    1,421.00
# 251  Mar-11          1,209.44                     14.00%    1,280.00
#
#     Copra price % Change  Cotton Price Cotton price % Change Fine wool Price  \
# ...

# %%
#Coluna com a média dos preços
media_precos = ['Cotton Price', 'Rubber Price']
df['mean'] = df[media_precos].mean(axis = 1)

# %%
df.head()
# Out:
#     Month Coarse wool Price Coarse wool price % Change Copra Price  \
# 0  Apr-90            482.34                          -         236
# 1  May-90            447.26                     -7.27%         234
# 2  Jun-90            440.99                     -1.40%         216
# 3  Jul-90            418.44                     -5.11%         205
# 4  Aug-90            418.44                      0.00%         198
#
#   Copra price % Change  Cotton Price Cotton price % Change Fine wool Price  \
# 0                    -          1.83                     -        1,071.63
# 1               -0.85%          1.89                 3.28%        1,057.18
# 2               -7.69%          1.99                 5.29%          898.24
# 3               -5.09%          2.01                 1.01%          895.83
# 4               -3.41%          1.79               -10.95%          951.22
#
#   Fine wool price % Change  Hard log Price  ... Plywood price % Change  \
# ...

# %%
# Primeiro modo de Consulta
df.query('(mean >=1.500 )')
# Out:
#       Month Coarse wool Price Coarse wool price % Change Copra Price  \
# 51   Jul-94            411.95                      4.43%         430
# 54   Oct-94            433.45                     -2.48%         409
# 55   Nov-94            446.07                      2.91%         464
# 56   Dec-94            426.04                     -4.49%         469
# 57   Jan-95            447.06                      4.93%         414
# ..      ...               ...                        ...         ...
# 354  Oct-19               NaN                        NaN         NaN
# 355  Nov-19               NaN                        NaN         NaN
# 356  Dec-19               NaN                        NaN         NaN
# 357  Jan-20               NaN                        NaN         NaN
# 358  Feb-20               NaN                        NaN         NaN
#
#     Copra price % Change  Cotton Price Cotton price % Change Fine wool Price  \
# ...
